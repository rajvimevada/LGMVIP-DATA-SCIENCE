# %% [markdown]
# # LetsGrowMore Virtual Internship Program

# %% [markdown]
# # LGMVIP-Data Science Internship-July-23

# %% [markdown]
# # By: Rajvi Mevada

# %% [markdown]
# # Task-2:  Prediction Using Decision Tree Algorithm (Intermediate level task)

# %% [markdown]
# ### Probelm Statement
# Create the Decision Tree classifier and visualize it graphically. The purpose is if we feed any new data to this classifier, it would be able to predict the right class accordingly.
#
# **Link for the dataset:** https://bit.ly/3kXTdox

# %% [markdown]
# ## Decision Tree Algorithm
# Decision Tree Algorithm is a popular and widely used algorithm in Machine Learning for classification and prediction tasks

# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import plot_confusion_matrix, classification_report
from sklearn import metrics
# %matplotlib inline

# %% [markdown]
# ## Load the dataset

# %%
df=pd.read_csv('Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# ## Checking null value

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.value_counts('Species')
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
df=df.drop(['Id'], axis=1)
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Data Visualization

# %%
#Pie plot to show the overall types of Iris classifications
df['Species'].value_counts().plot(kind = 'pie',  autopct = '%1.1f%%', shadow = True, explode = [0.08,0.08,0.08])
plt.title("types of Iris classifications",size=20)
# Out:
# Text(0.5, 1.0, 'types of Iris classifications')

# %%
#Correlation Heatmap
plt.figure(figsize=(9,7))
sns.heatmap(df.corr(),cmap='CMRmap',annot=True,linewidths=2)
plt.title("Correlation Graph",size=20)
plt.show()

# %%
sns.pairplot(df, hue='Species')

# %%
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm',hue='Species',data=df, palette = 'Set1')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %% [markdown]
# **Observation:**
#
# * Setosa has smaller sepal length but larger sepal width.
# * Versicolor lies in the middle of the other two species in terms of sepal length and width.
# * Virginica has larger sepal length but smaller sepal width.

# %%
sns.scatterplot(x='PetalLengthCm', y='PetalWidthCm', hue='Species', data=df)
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %% [markdown]
# **Observation:**
# * Setosa has smaller petal lengths and width.
# * Versicolor lies in the middle of the other two species in terms of petal length and width.
# * Virginica has the largest of petal length and width.

# %% [markdown]
# ## Checking Outliers

# %%
for column in df.columns[0:-1]:
    plt.figure(figsize=(10,5))
    sns.boxplot(x=(column), data=df)

# %%
Q1=df['SepalWidthCm'].quantile(0.25)
Q3=df['SepalWidthCm'].quantile(0.75)
IQR=Q3-Q1
print ("IQR: ",IQR)
lower_limit=Q1-(1.5*IQR)
print("lower_limit: ",lower_limit)
upper_limit=Q3+(1.5*IQR)
print("upper_limit: ",upper_limit)
df['SepalWidthCm']=np.where(df['SepalWidthCm']<lower_limit,lower_limit,df['SepalWidthCm'])
df['SepalWidthCm']=np.where(df['SepalWidthCm']>upper_limit,upper_limit,df['SepalWidthCm'])
# Out:
# IQR:  0.5
# lower_limit:  2.05
# upper_limit:  4.05

# %%
for column in df.columns[0:-1]:
    plt.figure(figsize=(10,5))
    sns.boxplot(x=(column),data=df)

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df['Species']=encoder.fit_transform(df['Species'])
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %%
encoder_name_mapping=dict(zip(encoder.classes_,encoder.transform(encoder.classes_)))
print(encoder_name_mapping)
# Out:
# {'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica': 2}

# %%
df['Species'].value_counts()
# Out:
# 0    50
# 1    50
# 2    50
# Name: Species, dtype: int64

# %% [markdown]
# ## Data Splitting

# %%
y= df['Species']
X= df.drop('Species', axis=1)

# %%
X_train, X_test, y_train, y_test =train_test_split(X,y,test_size=0.2,shuffle=True,random_state = 123)

# %%
X_train.shape
# Out:
# (120, 4)

# %%
y_train.shape
# Out:
# (120,)

# %% [markdown]
# ## Model Training and Evaluation

# %%
Model=DecisionTreeClassifier()
Model.fit(X_train,y_train)
Model.score(X_test,y_test)*100
# Out:
# 96.66666666666667

# %%
y_pred=Model.predict(X_test)

# %%
#plot confusion matrix
from sklearn.metrics import plot_confusion_matrix
print(plot_confusion_matrix(Model,X_test,y_test))
# Out:
# C:\Users\Harsh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x000001B1AA1F5250>

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       0.86      1.00      0.92         6
#            2       1.00      0.91      0.95        11
#
#     accuracy                           0.97        30
#    macro avg       0.95      0.97      0.96        30
# weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# ## Visualizing the decision tree

# %%
from sklearn import tree
features =['Sepal Length','Sepal Width','Petal Length','Petal Width']
species = ['setosa', 'versicolor', 'virginica']
fig = plt.figure(figsize = (13,13))
tree.plot_tree(Model, feature_names = features, class_names = species, filled = True)
# Out:
# [Text(0.5416666666666666, 0.9285714285714286, 'Petal Length <= 2.45\ngini = 0.665\nsamples = 120\nvalue = [37, 44, 39]\nclass = versicolor'),
#  Text(0.4583333333333333, 0.7857142857142857, 'gini = 0.0\nsamples = 37\nvalue = [37, 0, 0]\nclass = setosa'),
#  Text(0.625, 0.7857142857142857, 'Petal Width <= 1.75\ngini = 0.498\nsamples = 83\nvalue = [0, 44, 39]\nclass = versicolor'),
#  Text(0.4166666666666667, 0.6428571428571429, 'Petal Length <= 5.35\ngini = 0.156\nsamples = 47\nvalue = [0, 43, 4]\nclass = versicolor'),
#  Text(0.3333333333333333, 0.5, 'Petal Width <= 1.65\ngini = 0.085\nsamples = 45\nvalue = [0, 43, 2]\nclass = versicolor'),
#  Text(0.16666666666666666, 0.35714285714285715, 'Petal Length <= 4.95\ngini = 0.045\nsamples = 43\nvalue = [0, 42, 1]\nclass = versicolor'),
#  Text(0.08333333333333333, 0.21428571428571427, 'gini = 0.0\nsamples = 41\nvalue = [0, 41, 0]\nclass = versicolor'),
#  Text(0.25, 0.21428571428571427, 'Sepal Width <= 2.45\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]\nclass = versicolor'),
#  Text(0.16666666666666666, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(0.3333333333333333, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = versicolor'),
#  Text(0.5, 0.35714285714285715, 'Sepal Width <= 2.75\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]\nclass = versicolor'),
#  Text(0.4166666666666667, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(0.5833333333333334, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = versicolor'),
#  Text(0.5, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = virginica'),
#  Text(0.8333333333333334, 0.6428571428571429, 'Petal Length <= 4.85\ngini = 0.054\nsamples = 36\nvalue = [0, 1, 35]\nclass = virginica'),
#  Text(0.75, 0.5, 'Sepal Width <= 3.0\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]\nclass = versicolor'),
#  Text(0.6666666666666666, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(0.8333333333333334, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = versicolor'),
#  Text(0.9166666666666666, 0.5, 'gini = 0.0\nsamples = 34\nvalue = [0, 0, 34]\nclass = virginica')]

# %% [markdown]
# ## Prediction on random sample

# %%
prediction=Model.predict([[7.3,2.8,6.3, 1.8]])

if prediction==0:
    print('The given sample is Iris-setosa')
elif prediction==1:
    print('The given sample is Iris-versicolor')
else:
    print('The given sample is Iris-virginica')
# Out:
# The given sample is Iris-virginica
# C:\Users\Harsh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
#Predicting the output class for random values for petal and sepal length and width
#Predict the flower type for a flower with sepal length, sepal width, petal length, petal width as 5cm, 3.6cm, 1.4cm and 0.2cm respectively

prediction=Model.predict([[5, 3.6, 1.4 , 0.2]])
if prediction==0:
    print('The given sample is Iris-setosa')
elif prediction==1:
    print('The given sample is Iris-versicolor')
else:
    print('The given sample is Iris-virginica')
# Out:
# The given sample is Iris-setosa
# C:\Users\Harsh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
prediction=Model.predict([[9, 3.1, 5, 1.5]])
if prediction==0:
    print('The given sample is Iris-setosa')
elif prediction==1:
    print('The given sample is Iris-versicolor')
else:
    print('The given sample is Iris-virginica')
# Out:
# The given sample is Iris-versicolor
# C:\Users\Harsh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
prediction=Model.predict([[4.1, 3.0, 5.1, 1.8]])
if prediction==0:
    print('The given sample is Iris-setosa')
elif prediction==1:
    print('The given sample is Iris-versicolor')
else:
    print('The given sample is Iris-virginica')
# Out:
# The given sample is Iris-virginica
# C:\Users\Harsh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
